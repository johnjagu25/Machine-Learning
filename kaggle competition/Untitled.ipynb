# %%
import os

path = 'GM1901:\\'

files3 = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file or '.jpeg' in file:
            files3.append(os.path.join(r, file))

len(files3)
# Out:
# 0

# %%
list(os.walk("d:\\"))
# Out:
# [('c:\\',
#   ['$Recycle.Bin',
#    'Android',
#    'Config.Msi',
#    'Documents and Settings',
#    'Intel',
#    'MSOCache',
#    'Octave',
#    'PerfLogs',
#    'Program Files',
#    'Program Files (x86)',
#    'ProgramData',
#    'Recovery',
#    'System Volume Information',
#    'Users',
#    'Windows'],
#   ['$WINRE_BACKUP_PARTITION.MARKER',
#    'bootTel.dat',
#    'hiberfil.sys',
#    'pagefile.sys',
#    'swapfile.sys']),
#  ('c:\\$Recycle.Bin',
#   ['S-1-5-18',
#    'S-1-5-21-545691351-2883539799-484426694-1000',
#    'S-1-5-21-545691351-2883539799-484426694-1001'],
#   []),
#  ('c:\\$Recycle.Bin\\S-1-5-21-545691351-2883539799-484426694-1001',
#   ['$RG3LIHA', '$RR9ZHPQ.NET]'],
#   ['$I85RZG9.jpg', '$IMZKEBH.jpg', '$ITGKVM5.jpg', 'desktop.ini']),
#  ('c:\\$Recycle.Bin\\S-1-5-21-545691351-2883539799-484426694-1001\\$RG3LIHA',
#   ['rbtech'],
#   []),
#  ('c:\\$Recycle.Bin\\S-1-5-21-545691351-2883539799-484426694-1001\\$RG3LIHA\\rbtech',
#   ['node_modules', 'src'],
# ...

# %%
edrive = [ f.split("\\")[-1] for f in files]

# %%
ddrive = [ f.split("\\")[-1] for f in files2]

# %%
f = open('This PC\GM1901\Internal shared storage')
content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-69af49518829> in <module>()
# ----> 1 f = open('This PC\GM1901\Internal shared storage')
#       2 content = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'This PC\\GM1901\\Internal shared storage'

# %%
k = [1,2,3] + [4,5,6]

# %%
k
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
ffdrive = edrive + ddrive

# %%
len(ffdrive)
# Out:
# 70174
