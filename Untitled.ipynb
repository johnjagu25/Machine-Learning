# %%
import numpy as np
from sklearn.preprocessing import normalize

x = np.random.rand(1000)*10
norm1 = x / np.linalg.norm(x)
norm1
# Out:
# array([0.0269052 , 0.00645965, 0.01996863, 0.01365861, 0.03693963,
#        0.01133846, 0.00020164, 0.00661356, 0.00160523, 0.0278426 ,
#        0.05322302, 0.00449635, 0.04734735, 0.03015983, 0.05341821,
#        0.02455501, 0.03707389, 0.02708446, 0.01973974, 0.01896526,
#        0.01528578, 0.02715302, 0.015365  , 0.01369069, 0.01160239,
#        0.04764945, 0.00465889, 0.04647763, 0.01215366, 0.03804309,
#        0.02810102, 0.00248956, 0.05369505, 0.05042208, 0.02154699,
#        0.00094046, 0.04866514, 0.003402  , 0.02717283, 0.02591629,
#        0.00150526, 0.00410935, 0.03385858, 0.04441178, 0.00979851,
#        0.01879072, 0.02229398, 0.01363774, 0.05481762, 0.01623774,
#        0.0013516 , 0.00483335, 0.01377821, 0.04158169, 0.02121519,
#        0.00781025, 0.00059427, 0.0299541 , 0.03765681, 0.0378102 ,
#        0.04408003, 0.04822373, 0.00143617, 0.01503615, 0.0360083 ,
#        0.02919842, 0.03661172, 0.00496962, 0.00925844, 0.05163607,
# ...

# %%
sum((x - np.min(x))/(np.max(x)-np.min(x)))
# Out:
# 494.7278605910411

# %%
0.5 * x.T.dot(x)
# Out:
# 7.0

# %%
np.linalg.norm(x[:2])
# Out:
# 0.2860846966351397

# %%
from sklearn.datasets import load_iris

# %%
dataset = load_iris()

# %%
np.linalg.norm(dataset.data[:2,0:2])
# Out:
# 8.442156122697567

# %%
dataset.data[:3,0:3]/np.linalg.norm(dataset.data[:3,0:3],ord=1)
# Out:
# array([[0.34693878, 0.23809524, 0.0952381 ],
#        [0.33333333, 0.20408163, 0.0952381 ],
#        [0.31972789, 0.21768707, 0.08843537]])

# %%
np.sum(dataset.data[:2,0:2])
# Out:
# 16.5
